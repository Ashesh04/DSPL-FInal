# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashesh04/DSPL-FInal/blob/main/preprocessed_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data_path = '/content/drive/MyDrive/demographics_residing_lka.csv'
data_path
# Out:
# '/content/drive/MyDrive/demographics_residing_lka.csv'

# %%
data_path = '/content/drive/MyDrive/demographics_residing_lka.csv'
df = pd.read_csv(data_path)
df.head()
# Out:
#          Year Country of Origin Code Country of Asylum Code  \
# 0  #date+year   #country+code+origin   #country+code+asylum
# 1        2001                    AFG                    LKA
# 2        2001                    IRQ                    LKA
# 3        2001                    IRQ                    LKA
# 4        2001                    LKA                    LKA
#
#   Country of Origin Name Country of Asylum Name             Population Type  \
# 0   #country+name+origin   #country+name+asylum  #indicator+population_type
# 1            Afghanistan              Sri Lanka                         ASY
# 2                   Iraq              Sri Lanka                         ASY
# 3                   Iraq              Sri Lanka                         REF
# 4              Sri Lanka              Sri Lanka                         IDP
#
#                                location urbanRural accommodationType  \
# 0                                   NaN        NaN               NaN
# ...

# %%
# Instead of trying to drop by a specific numerical index,
# reset the index and then drop the first row if needed.
df = df.reset_index(drop=True)  # Reset the index
df = df.drop(index=0)  # Drop the first row (now with index 0)
df.head()
# Out:
#    Year Country of Origin Code Country of Asylum Code Country of Origin Name  \
# 1  2001                    AFG                    LKA            Afghanistan
# 2  2001                    IRQ                    LKA                   Iraq
# 3  2001                    IRQ                    LKA                   Iraq
# 4  2001                    LKA                    LKA              Sri Lanka
# 5  2001                    LKA                    LKA              Sri Lanka
#
#   Country of Asylum Name Population Type  \
# 1              Sri Lanka             ASY
# 2              Sri Lanka             ASY
# 3              Sri Lanka             REF
# 4              Sri Lanka             IDP
# 5              Sri Lanka             IDP
#
#                                location urbanRural accommodationType  \
# 1                               Colombo          U                 U
# 2                               Colombo          U                 U
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Country of Origin Code', 'Country of Asylum Code',
#        'Country of Origin Name', 'Country of Asylum Name', 'Population Type',
#        'location', 'urbanRural', 'accommodationType', 'Female 0-4',
#        'Female 5-11', 'Female 12-17', 'Female 18-59', 'Female 60 or more',
#        'Female Unknown', 'Female Total', 'Male 0-4', 'Male 5-11', 'Male 12-17',
#        'Male 18-59', 'Male 60 or more', 'Male Unknown', 'Male Total', 'Total'],
#       dtype='object')

# %%
df.drop(['Country of Origin Code', 'Country of Asylum Code'], axis=1, inplace=True, errors='ignore')
df.columns
# Out:
# Index(['Year', 'Country of Origin Name', 'Country of Asylum Name',
#        'Population Type', 'location', 'urbanRural', 'accommodationType',
#        'Female 0-4', 'Female 5-11', 'Female 12-17', 'Female 18-59',
#        'Female 60 or more', 'Female Unknown', 'Female Total', 'Male 0-4',
#        'Male 5-11', 'Male 12-17', 'Male 18-59', 'Male 60 or more',
#        'Male Unknown', 'Male Total', 'Total'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 1 to 750
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    750 non-null    object
#  1   Country of Origin Name  750 non-null    object
#  2   Country of Asylum Name  750 non-null    object
#  3   Population Type         750 non-null    object
#  4   location                750 non-null    object
#  5   urbanRural              750 non-null    object
#  6   accommodationType       750 non-null    object
#  7   Female 0-4              750 non-null    object
#  8   Female 5-11             750 non-null    object
#  9   Female 12-17            750 non-null    object
#  10  Female 18-59            750 non-null    object
#  11  Female 60 or more       750 non-null    object
#  12  Female Unknown          750 non-null    object
#  13  Female Total            750 non-null    object
# ...

# %%
# List of columns to convert
columns_to_convert = ['Female 0-4', 'Female 5-11', 'Female 12-17', 'Female 18-59',
       'Female 60 or more', 'Female Unknown', 'Female Total', 'Male 0-4',
       'Male 5-11', 'Male 12-17', 'Male 18-59', 'Male 60 or more',
       'Male Unknown', 'Male Total', 'Total']

# Convert columns to numeric, handling errors
for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce').astype('Int64') # coerce invalid values to NaN, then convert to Int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 1 to 750
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    750 non-null    object
#  1   Country of Origin Name  750 non-null    object
#  2   Country of Asylum Name  750 non-null    object
#  3   Population Type         750 non-null    object
#  4   location                750 non-null    object
#  5   urbanRural              750 non-null    object
#  6   accommodationType       750 non-null    object
#  7   Female 0-4              750 non-null    Int64
#  8   Female 5-11             750 non-null    Int64
#  9   Female 12-17            750 non-null    Int64
#  10  Female 18-59            750 non-null    Int64
#  11  Female 60 or more       750 non-null    Int64
#  12  Female Unknown          750 non-null    Int64
#  13  Female Total            750 non-null    Int64
# ...

# %%
# Check for missing values in the entire DataFrame
missing_values1 = df.isnull().sum()

# Display the count of missing values for each column
print(missing_values1)
# Out:
# Year                      0
# Country of Origin Name    0
# Country of Asylum Name    0
# Population Type           0
# location                  0
# urbanRural                0
# accommodationType         0
# Female 0-4                0
# Female 5-11               0
# Female 12-17              0
# Female 18-59              0
# Female 60 or more         0
# Female Unknown            0
# Female Total              0
# Male 0-4                  0
# Male 5-11                 0
# Male 12-17                0
# Male 18-59                0
# Male 60 or more           0
# Male Unknown              0
# Male Total                0
# Total                     0
# dtype: int64

# %%
# Drop rows with any missing values
df.dropna(inplace=True)
missing_vsalues2 = df.isnull().sum()
print(missing_vsalues2)
# Out:
# Year                      0
# Country of Origin Name    0
# Country of Asylum Name    0
# Population Type           0
# location                  0
# urbanRural                0
# accommodationType         0
# Female 0-4                0
# Female 5-11               0
# Female 12-17              0
# Female 18-59              0
# Female 60 or more         0
# Female Unknown            0
# Female Total              0
# Male 0-4                  0
# Male 5-11                 0
# Male 12-17                0
# Male 18-59                0
# Male 60 or more           0
# Male Unknown              0
# Male Total                0
# Total                     0
# dtype: int64

# %%
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
# !pip install matplotlib seaborn

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'df' is your DataFrame and 'columns_to_convert' is your list of numerical columns
# ... (Your previous code to load and clean the data) ...

# Create horizontal box plots for numerical columns with a distinct blue color
plt.figure(figsize=(15, 10))  # Adjust overall figure size
for i, column in enumerate(columns_to_convert):
    plt.subplot(4, 4, i + 1)  # Arrange plots in a grid (adjust rows/cols as needed)
    sns.boxplot(x=df[column], color='royalblue')  # Use 'x' for horizontal orientation
    plt.title(f"Box Plot of {column}")
    plt.tight_layout()  # Prevent overlapping of plots

plt.show()
